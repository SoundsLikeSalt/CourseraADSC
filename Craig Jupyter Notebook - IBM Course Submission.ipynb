# %% [markdown]
# # **My Jupyter Notebook on IBM Data Science Experience**

# %% [markdown]
# **By Jonathan Craig**
# Desired Occupation: Arts Administration and Nonprofit Finance professional

# %% [markdown]
# _I am interested in data science because the ability to more efficiently leverage analytical tools to understand data is directly applicable to the finance world._

# %% [markdown]
# ### Code in Cell 5 is meant to print the text "Stay Healthy"

# %%
print ("Stay Healthy")
# Out:
# Stay Healthy

# %% [markdown]
# * Bullet 1
# * ~Bullet 2~
# * Bullet 3
#     1. Nested numbered list 1
#     2. Nested numbered list 2
#     3. [~Nested numbered list 3~](https://www.google.com)
#
# <mark style="background-color: lightblue"> _lightly highlighted text_ </mark>
